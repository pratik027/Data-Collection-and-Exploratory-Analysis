# %% [markdown]
# # Part3

# %%
install.packages("ggmap", repos = "http://cran.us.r-project.org")
# Out:
# package 'ggmap' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\prati\AppData\Local\Temp\RtmpyQfPUn\downloaded_packages
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.0     v purrr   0.2.5
# v tibble  1.4.2     v dplyr   0.7.6
# v tidyr   0.8.1     v stringr 1.3.1
# v readr   1.1.1     v forcats 0.3.0
# Warning message:
# "package 'ggplot2' was built under R version 3.5.2"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
install.packages("tidyverse", repos = "http://cran.us.r-project.org")
# Out:
# Warning message:
# "package 'tidyverse' is in use and will not be installed"Warning message:
# "package 'ggmap' was built under R version 3.5.2"Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.
# Error: Google now requires an API key.
#        See ?register_google for details.
# Traceback:
#
# 1. geocode(c("64 Montrose avenue, buffalo")[1], output = "all")
# 2. stop("Google now requires an API key.", "\n       See ?register_google for details.",
#  .     call. = FALSE)

# %%
register_google(key = "AIzaSyCK5edaQsaKWnSvkPMEJwSLP39s6jx9-rI")
geo=geocode("64 Montrose,buffalo",output="all")
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=64+Montrose,buffalo&key=xxx-rI
# $results
# $results[[1]]
# $results[[1]]$address_components
# $results[[1]]$address_components[[1]]
# $results[[1]]$address_components[[1]]$long_name
# [1] "64"
#
# $results[[1]]$address_components[[1]]$short_name
# [1] "64"
#
# $results[[1]]$address_components[[1]]$types
# $results[[1]]$address_components[[1]]$types[[1]]
# [1] "street_number"
#
#
#
# $results[[1]]$address_components[[2]]
# $results[[1]]$address_components[[2]]$long_name
# [1] "Montrose Avenue"
#
# $results[[1]]$address_components[[2]]$short_name
# [1] "Montrose Ave"
#
# $results[[1]]$address_components[[2]]$types
# $results[[1]]$address_components[[2]]$types[[1]]
# [1] "route"
#
#
#
# $results[[1]]$address_components[[3]]
# $results[[1]]$address_components[[3]]$long_name
# [1] "University"
#
# $results[[1]]$address_components[[3]]$short_name
# [1] "University"
#
# $results[[1]]$address_components[[3]]$types
# ...

# %%
geo_latlona=geocode("64 Montrose,buffalo",output=c("latlona",nameType = c("long", )
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=64+Montrose,buffalo&key=xxx-rI

# %%
geo_all
# Out:
# $results
# $results[[1]]
# $results[[1]]$address_components
# $results[[1]]$address_components[[1]]
# $results[[1]]$address_components[[1]]$long_name
# [1] "64"
#
# $results[[1]]$address_components[[1]]$short_name
# [1] "64"
#
# $results[[1]]$address_components[[1]]$types
# $results[[1]]$address_components[[1]]$types[[1]]
# [1] "street_number"
#
#
#
# $results[[1]]$address_components[[2]]
# $results[[1]]$address_components[[2]]$long_name
# [1] "Montrose Avenue"
#
# $results[[1]]$address_components[[2]]$short_name
# [1] "Montrose Ave"
#
# $results[[1]]$address_components[[2]]$types
# $results[[1]]$address_components[[2]]$types[[1]]
# [1] "route"
#
#
#
# $results[[1]]$address_components[[3]]
# $results[[1]]$address_components[[3]]$long_name
# [1] "University"
#
# $results[[1]]$address_components[[3]]$short_name
# [1] "University"
#
# $results[[1]]$address_components[[3]]$types
# $results[[1]]$address_components[[3]]$types[[1]]
# [1] "neighborhood"
#
# ...

# %%
geo_more
# Out:
#   lon       lat      type    loctype address
# 1 -78.82731 42.95566 premise rooftop 64 montrose ave, buffalo, ny 14214, usa
#   north  south    east      west
# 1 42.957 42.95431 -78.82597 -78.82867

# %%
geo_latlona
# Out:
#   lon       lat      address
# 1 -78.82731 42.95566 64 montrose ave, buffalo, ny 14214, usa

# %%
loc<-c("64 Montrose,buffalo","San Jose","miami")
geo=geocode(loc,output="all",nameType = c("long") )
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=64+Montrose,buffalo&key=xxx-rI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=San+Jose&key=xxx-rI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=miami&key=xxx-rI

# %%
colnames(data.frame(geo))
data.frame(geo)[1]['results']['address_components']
# Out:
#   [1] "results.address_components.long_name"
#   [2] "results.address_components.short_name"
#   [3] "results.address_components..street_number."
#   [4] "results.address_components.long_name.1"
#   [5] "results.address_components.short_name.1"
#   [6] "results.address_components..route."
#   [7] "results.address_components.long_name.2"
#   [8] "results.address_components.short_name.2"
#   [9] "results.address_components.types..neighborhood."
#  [10] "results.address_components.types..political."
#  [11] "results.address_components.long_name.3"
#  [12] "results.address_components.short_name.3"
#  [13] "results.address_components.types..locality."
#  [14] "results.address_components.types..political..1"
#  [15] "results.address_components.long_name.4"
#  [16] "results.address_components.short_name.4"
#  [17] "results.address_components.types..administrative_area_level_2."
#  [18] "results.address_components.types..political..2"
#  [19] "results.address_components.long_name.5"
# ...

# %%
geo
# Out:
# [[1]]
# [[1]]$results
# [[1]]$results[[1]]
# [[1]]$results[[1]]$address_components
# [[1]]$results[[1]]$address_components[[1]]
# [[1]]$results[[1]]$address_components[[1]]$long_name
# [1] "64"
#
# [[1]]$results[[1]]$address_components[[1]]$short_name
# [1] "64"
#
# [[1]]$results[[1]]$address_components[[1]]$types
# [[1]]$results[[1]]$address_components[[1]]$types[[1]]
# [1] "street_number"
#
#
#
# [[1]]$results[[1]]$address_components[[2]]
# [[1]]$results[[1]]$address_components[[2]]$long_name
# [1] "Montrose Avenue"
#
# [[1]]$results[[1]]$address_components[[2]]$short_name
# [1] "Montrose Ave"
#
# [[1]]$results[[1]]$address_components[[2]]$types
# [[1]]$results[[1]]$address_components[[2]]$types[[1]]
# [1] "route"
#
#
#
# [[1]]$results[[1]]$address_components[[3]]
# [[1]]$results[[1]]$address_components[[3]]$long_name
# [1] "University"
#
# [[1]]$results[[1]]$address_components[[3]]$short_name
# [1] "University"
#
# [[1]]$results[[1]]$address_components[[3]]$types
# ...

# %%
geo_more
# Out:
#   lon       lat      type    loctype address
# 1 -78.82731 42.95566 premise rooftop 64 montrose ave, buffalo, ny 14214, usa
#   north  south    east      west
# 1 42.957 42.95431 -78.82597 -78.82867

# %%
install.packages("revgeo", repos = "http://cran.us.r-project.org")
install.packages("dplyr", repos = "http://cran.us.r-project.org")
install.packages("sf", repos = "http://cran.us.r-project.org")
install.packages("purrr", repos = "http://cran.us.r-project.org")
install.packages("raster", repos = "http://cran.us.r-project.org")
install.packages("osmdata", repos = "http://cran.us.r-project.org")
install.packages("spDataLarge", repos = "http://cran.us.r-project.org")
# Out:
# package 'revgeo' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\prati\AppData\Local\Temp\RtmpyQfPUn\downloaded_packages
# also installing the dependencies 'cli', 'fansi', 'pillar', 'pkgconfig', 'Rcpp', 'rlang', 'tibble', 'tidyselect'
#
# Warning message:
# "packages 'tibble', 'dplyr' are in use and will not be installed"
# package 'cli' successfully unpacked and MD5 sums checked
# package 'fansi' successfully unpacked and MD5 sums checked
# package 'pillar' successfully unpacked and MD5 sums checked
# package 'pkgconfig' successfully unpacked and MD5 sums checked
# package 'Rcpp' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'Rcpp'"
# package 'rlang' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'rlang'"
# package 'tidyselect' successfully unpacked and MD5 sums checked
# Warning message:
# ...

# %%
# library(sf)
library(dplyr)
library(purrr)
library(raster)
library(osmdata)
library(spDataLarge)
library(ggmap)
# Out:
# Warning message:
# "package 'raster' was built under R version 3.5.2"Loading required package: sp
# Warning message:
# "package 'sp' was built under R version 3.5.2"

# %%
library(revgeo)

# %%
revgeo(longitude=-78.827235, latitude=42.9557182, output='frame')
